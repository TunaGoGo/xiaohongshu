# %%
import requests

# %%
html = """
<!DOCTYPE html>
<html lang="zh-CN">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Python 核心代码题</title>
  <link rel="stylesheet" href="styles.css">
</head>
<body>
  <div class="container">
    <div class="header">
      <img src="python-logo.png" alt="Python Logo" class="logo">
      <h1>150道Python核心代码题</h1>
    </div>
    <p class="subtitle">练完这套，你的Python就🐵了！</p>
    <div class="code-block">
      <pre>
<code>
<span class="keyword">import</span> os
<span class="keyword">import</span> sys

<span class="keyword">if</span> <span class="variable">__name__</span> == <span class="string">"__main__"</span>:
    pre = <span class="function">input</span>(<span class="string">"请输入需要添加的前缀:"</span>)
    mark = <span class="string">"[{}]"</span>.format(pre)
    old_names = os.listdir()
    <span class="keyword">for</span> old_name <span class="keyword">in</span> old_names:
        <span class="keyword">if</span> old_name != sys.argv[<span class="number">0</span>]:
            os.rename(old_name, mark + old_name)
</code>
      </pre>
    </div>
  </div>
</body>
</html>
"""

# %%
css = """
body {
  font-family: "Arial", sans-serif;
  background-color: #f9f9f9;
  margin: 0;
  padding: 0;
}

.container {
  width: 90%;
  max-width: 800px;
  margin: 30px auto;
  background-color: white;
  padding: 20px;
  border-radius: 10px;
  box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
}

.header {
  text-align: center;
}

.logo {
  width: 60px;
  height: auto;
}

h1 {
  font-size: 24px;
  color: #333;
}

.subtitle {
  text-align: center;
  font-size: 16px;
  color: #555;
  margin-top: 10px;
}

.code-block {
  background-color: #f4f4f4;
  padding: 20px;
  border-radius: 8px;
  margin-top: 20px;
  overflow-x: auto;
}

pre {
  margin: 0;
}

code {
  font-family: "Courier New", monospace;
  color: #333;
}

.keyword {
  color: #d73a49;
  font-weight: bold;
}

.string {
  color: #032f62;
}

.function {
  color: #6f42c1;
}

.variable {
  color: #005cc5;
}

.number {
  color: #005cc5;
}

"""
